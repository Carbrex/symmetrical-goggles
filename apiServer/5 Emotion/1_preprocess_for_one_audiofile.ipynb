# %% [markdown]
# <a href="https://colab.research.google.com/github/MeidanGR/SpeechEmotionRecognition_Realtime/blob/main/1_preprocess_for_one_audiofile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Speech Emotion Recognition (Classification) in real-time using Deep LSTM layers**
# ### ***Data preprocess representation for a single audio file***
# ---
#
# ### Final project (B.Sc. requirement)
# Development by **Meidan Greenberg & Linoy Hadad.**
#
# Instructor: **Dr. Dima Alberg**
#
# Industial Engineering and Management dept.
#
# SCE Collage, Israel.

# %% [markdown]
# # **LIBRARIES & GOOGLE AUTH**

# %%
# %pip install pydub
# %pip install noisereduce
# Out:
# /usr/bin/zsh: /home/histox/miniconda3/envs/speechRealtime/lib/libtinfo.so.6: no version information available (required by /usr/bin/zsh)
# Requirement already satisfied: pydub in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (0.25.1)
# Note: you may need to restart the kernel to use updated packages.
# /usr/bin/zsh: /home/histox/miniconda3/envs/speechRealtime/lib/libtinfo.so.6: no version information available (required by /usr/bin/zsh)
# Requirement already satisfied: noisereduce in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (3.0.0)
# Requirement already satisfied: scipy in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from noisereduce) (1.11.2)
# Requirement already satisfied: matplotlib in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from noisereduce) (3.8.0)
# Requirement already satisfied: librosa in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from noisereduce) (0.10.1)
# Requirement already satisfied: numpy in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from noisereduce) (1.24.3)
# Requirement already satisfied: tqdm in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from noisereduce) (4.66.1)
# Requirement already satisfied: audioread>=2.1.9 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from librosa->noisereduce) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from librosa->noisereduce) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from librosa->noisereduce) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from librosa->noisereduce) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from librosa->noisereduce) (0.57.1)
# Requirement already satisfied: soundfile>=0.12.1 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from librosa->noisereduce) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from librosa->noisereduce) (1.7.0)
# Requirement already satisfied: soxr>=0.3.2 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from librosa->noisereduce) (0.3.6)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from librosa->noisereduce) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from librosa->noisereduce) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from librosa->noisereduce) (1.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from matplotlib->noisereduce) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from matplotlib->noisereduce) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from matplotlib->noisereduce) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from matplotlib->noisereduce) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from matplotlib->noisereduce) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from matplotlib->noisereduce) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from matplotlib->noisereduce) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from matplotlib->noisereduce) (6.0.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->noisereduce) (3.16.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from numba>=0.51.0->librosa->noisereduce) (0.40.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from pooch>=1.0->librosa->noisereduce) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from pooch>=1.0->librosa->noisereduce) (2.31.0)
# Requirement already satisfied: six>=1.5 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa->noisereduce) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa->noisereduce) (1.15.1)
# Requirement already satisfied: pycparser in /home/histox/miniconda3/envs/speechRealtime/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->noisereduce) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/histox/miniconda3/envs/speech/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%capture
import os
import numpy as np

from pydub import AudioSegment, effects
import librosa
import noisereduce as nr

import matplotlib.pyplot as plt
from librosa import display   
import IPython.display as ipd

# %% [markdown]
# # **DATA PREPROCESS REPRESENTATION**
# This notebook present the data preprocessing for a single audio file.
# The preprocess is described in the following diagram:
# ![Data preprocessing.png](data:image/png;base64,...)

# %% [markdown]
# ## **Diagram Explanation**
# In general, The following data is extracted from each audio file:
# 1.   **Emotion representation**
#
#     *   RAVDESS: The filename contains a number that represents an emotion, e.g. 03 is happy.
#     *   TESS: The filename contains a direct representation of an emotion, e.g 'happy'.
#
#
# 2.   **Sample Rate**: number of audio samples per second. RAVDESS database was recorded in 48kHz, and the TESS database was recorded in 22.5kHz.
#
# 3. **The audio** is processed in the following order:
#
#
# *   'AudioSegment' instance: The audio is loaded to an object by the library 'AudioSegment'.
# *   Normalization: Each 'AudioSegment' object is normalized to + 5.0 dBFS.
#
# *   Transforming the object to an array of samples is crucial for the rest of the preprocessing.
# *   Trimming the silence in the beginning and the end, to get rid of unnecessary data.
# *   Padding every audio file to the same length, for length equalization.
# *   Noise reduction is being performed.
# ---

# %% [markdown]
# ## **Audio preprocess for a single file**

# %%
# Define file path for a single file.
path = '../Dataset/RAVDASS/Actor_02/03-01-01-01-01-02-02.wav'

# %%
# 1. Load the audio file into an 'AudioSegment' object, and extract the sample rate. 
#    'x' is an array of samples that is only relevant for visualization at this part.

rawsound = AudioSegment.from_file(path)
x, sr = librosa.load(path)

plt.figure(figsize=(12,1))
# librosa.display.waveshow(x, sr=sr)
plt.title('Initial audio')

rawsound
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %% [markdown]
# The actual audio as well as the 'y' axis range suggests that the initial audio is very low-volumed. This can interfere with the feature extraction validity.

# %%
# 2. Normalize to +5.0 dBFS, Transform audio signals to an array.

normalizedsound = effects.normalize(rawsound, headroom = 5.0) 
normal_x = np.array(normalizedsound.get_array_of_samples(), dtype = 'float32')

plt.figure(figsize=(12,2))
# librosa.display.waveshow(normal_x, sr=sr)
plt.title('Normalized audio')

normalizedsound
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
# 3. Trim silence in the beginning and end.

xt, index = librosa.effects.trim(normal_x, top_db = 30)

plt.figure(figsize=(6,2))
# librosa.display.waveplot(xt, sr)
plt.title('Trimmed audio')

ipd.display(ipd.Audio(data = xt, rate=sr))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 4. Right-side padding for length equalization.
#    173056 = maximum lengthed audio (the extraction of this value is performed in the "SpeechEmotionRecognion_Model" notebook.)

padded_x = np.pad(xt, (0, 173056-len(xt)), 'constant')

plt.figure(figsize=(12,2))
# librosa.display.waveplot(padded_x, sr)
plt.title('Padded audio')

ipd.display(ipd.Audio(data = padded_x, rate=sr))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 5. Noise reduction
#    Note: although there is no noise to reduce from RAVDESS nor TESS databases, reduce_noise function by noisereduce library attributes a uniform stamper to the audio files. 

final_x = nr.reduce_noise(y=padded_x, y_noise=padded_x, sr=sr)

plt.figure(figsize=(12,2))
# librosa.display.waveplot(final_x, sr)
plt.title('Noise-reduced audio')

ipd.display(ipd.Audio(data = final_x, rate=sr))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## **Features extraction for a single file**
# The selected features being extracted with *librosa* for the speech emotion recognition model are:
#
# 1.   Energy - Root Mean Square (RMS)
# 2.   Zero Crossed Rate (ZCR)
# 3.   Mel-Frequency Cepstral Coefficients (MFCCs)
#
# With frame_length = 2048, hop_lentgh = 512.
#
# Explanation:
#
# Every 2048 samples (sequence of ~0.058 seconds on average) are being analyzed and translated to 4 sequential feature values (2048 / 512 = 4).
#
# In total, for an audio file lengthed 173056 samples, considering the last sample, 339 sequential values are returned for each feature  (173056+1 / 512 = 339).

# %%
# Feature extraction

frame_length = 2048
hop_length = 512

f1 = librosa.feature.rms(y=final_x, frame_length=frame_length, hop_length=hop_length) # Energy - Root Mean Square (RMS)
print('Energy shape:', f1.shape)
f2 = librosa.feature.zero_crossing_rate(y=final_x, frame_length=frame_length, hop_length=hop_length) # Zero Crossed Rate (ZCR)
print('ZCR shape:', f2.shape)
f3 = librosa.feature.mfcc(y=final_x, sr=sr, S=None, n_mfcc=13, hop_length = hop_length) # MFCCs
print('MFCCs shape:', f3.shape)
# Out:
# Energy shape: (1, 339)
# ZCR shape: (1, 339)
# MFCCs shape: (13, 339)

# %% [markdown]
# # **CONCLUSIONS**
#
# This notebook presents a **partial** preprocess for one audio file.
# The audio preprocess has been executed as well as the extraction of the sample rate, and feature extraction has been shown as well. The full preprocess is executed in "2_model" notebook.
#
# All features have 339 time-steps, thus, all of the data is equally lengthed, as well as homogeneous.
